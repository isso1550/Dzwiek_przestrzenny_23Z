# %%
import angleGuesser

filename = "../Dokumenty/Materialy/Audio/mowaLP.wav"
filename = "../Audio/main.wav"
angleGuesser.guessAngle(filename)
# Out:
# Kąty podane są idąc od godziny 12 na tarczy zegara zgodnie z ruchem wskazówek
# 16711 9648
# 30.00051608727896
# Przypuszczenie na podstawie roznic w amplitudach przy zalozeniu CPP: -30.00051608727896
# Przypuszczenie na podstawie roznic w amplitudach przy zalozeniu LP: -24.115861754998292
# Przypuszczenie na podstawie przesuniecia syngalow: [-28.63098984]
# Przypuszczenie na podstawie analizy przesuniecia sygnalow alternatywna metoda: [-28.63098984]

# %%
import matplotlib.pyplot as plt
import filemanager

fr, obj = filemanager.loadSignal(filename)
left, right = filemanager.getStereoChannels(fr, obj)

# %%
plt.plot(left[9500:10000], label = "left")
plt.plot(right[9500:10000], label = "right")
plt.legend()
