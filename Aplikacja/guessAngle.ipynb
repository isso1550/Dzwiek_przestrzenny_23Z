# %%
import angleGuesser

filename = "../Dokumenty/Materialy/Audio/mowaLP.wav"
filename = "../Audio/main.wav"
filename = "../Dokumenty/Materialy/Audio/mowaDelay1.wav"
angleGuesser.guessAngle(filename)
# Out:
# Kąty podane są idąc od godziny 12 na tarczy zegara zgodnie z ruchem wskazówek
# Przypuszczenie na podstawie roznic w amplitudach przy zalozeniu CPP: 0.0
# Przypuszczenie na podstawie roznic w amplitudach przy zalozeniu LP: 0.0
# Przypuszczenie na podstawie przesuniecia syngalow: [45.95137433]
# Przypuszczenie na podstawie analizy przesuniecia sygnalow alternatywna metoda: [45.95137433]

# %%
import matplotlib.pyplot as plt
import filemanager

fr, obj = filemanager.loadSignal(filename)
left, right = filemanager.getStereoChannels(fr, obj)

# %%
plt.plot(left[9500:10000], label = "left")
plt.plot(right[9500:10000], label = "right")
plt.legend()
